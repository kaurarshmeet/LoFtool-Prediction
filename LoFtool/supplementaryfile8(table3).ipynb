# %%
"""
Supplementary File 8: Running Models//Table 3
- took input from CHATGPT in this code 
- learned from: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
- learned from: https://scikit-learn.org/0.15/modules/model_evaluation.html
""""

# %%
#read stuff in 
import numpy as np 
import pandas as pd 
df_loftool_log = pd.read_csv('df_loftool_log.csv')

# %%
#knn regressor univariate feature selection (F regression) 
#Univariate Feature Selection (F Regression)

#got input from chatgpt here
#learned from here too: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
#learned (also) from here: https://stephenallwright.com/cross_val_score-sklearn
#https://grsahagian.medium.com/what-is-random-state-42-d803402ee76b 

import sklearn
from sklearn.neighbors import KNeighborsRegressor
import numpy as np 
import pandas as pd 

KNN = KNeighborsRegressor()

X = df_loftool_log[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_log['LoFtool'] 

#regular evaluation 
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 41)  
KNN.fit(X_train, y_train) 

y_pred = KNN.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = KNN.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training) 

#cross validation 
print("Loftool dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.8902620207001044 mse: 0.01457860525322148 rmse: 0.12074189518647403 mae: 0.039480597264911356 ev: 0.8902766887076894
# r2_train: 0.937135179373195 mse_train: 0.008261710318303259 rmse_training: 0.09089395094451148 mae_training: 0.027571620302448772 ev_training: 0.9371524090541774
# Loftool dataset:
# Cross-validation score for Loftool dataset: [0.09171079 0.40643756 0.56050495 0.6160061  0.44038318]
# Average cross-validation score for Loftool dataset: 0.4230085143994174
# R2 Score for Loftool dataset: [0.09171079 0.40643756 0.56050495 0.6160061  0.44038318]
# Average R2 score for Loftool dataset: 0.4230085143994174
# MSE score for Loftool dataset: [-0.09929966 -0.07275241 -0.04780536 -0.06415473 -0.0745982 ]
# Average MSE score for Loftool dataset: -0.071722071802825
# RMSE score for Loftool dataset: [-0.31511849 -0.26972654 -0.21864437 -0.25328785 -0.27312671]
# Average RMSE score for Loftool dataset: -0.26598078987466334
# ...

# %%
#knn regressor univariate feature selection (F regression)  (POS, cDNA, CDS_positon, Protein_positon removed) 
#Univariate Feature Selection (F Regression)

#got input from chatgpt here
#learned from here too: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
#learned (also) from here: https://stephenallwright.com/cross_val_score-sklearn
#https://grsahagian.medium.com/what-is-random-state-42-d803402ee76b 

import sklearn
from sklearn.neighbors import KNeighborsRegressor
import numpy as np 
import pandas as pd 

KNN = KNeighborsRegressor()

X = df_loftool_log[['STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_log['LoFtool'] 

#regular evaluation 
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 41)  
KNN.fit(X_train, y_train) 

y_pred = KNN.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = KNN.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training) 

#cross validation 
print("Loftool dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9823696798616192 mse: 0.0023421743267476036 rmse: 0.04839601560818415 mae: 0.020246536455310778 ev: 0.98238626579445
# r2_train: 0.9892791674829454 mse_train: 0.0014089344683373582 rmse_training: 0.03753577584568298 mae_training: 0.015230701210562688 ev_training: 0.9892847836581667
# Loftool dataset:
# Cross-validation score for Loftool dataset: [0.94491611 0.96604555 0.91787503 0.96908461 0.95357494]
# Average cross-validation score for Loftool dataset: 0.950299247911568
# R2 Score for Loftool dataset: [0.94491611 0.96604555 0.91787503 0.96908461 0.95357494]
# Average R2 score for Loftool dataset: 0.950299247911568
# MSE score for Loftool dataset: [-0.0060221  -0.00416177 -0.00893301 -0.0051651  -0.00618857]
# Average MSE score for Loftool dataset: -0.006094110017818151
# RMSE score for Loftool dataset: [-0.07760221 -0.06451175 -0.0945146  -0.07186866 -0.07866744]
# Average RMSE score for Loftool dataset: -0.07743293322156881
# ...

# %%
#Univariate feature selection (f regression) 
import sklearn
from sklearn.tree import DecisionTreeRegressor
import numpy as np 
import pandas as pd 


X = df_loftool_log[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_log['LoFtool'] 

Decision_Tree_Regressor = DecisionTreeRegressor() 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

Decision_Tree_Regressor.fit(X_train, y_train) 

y_pred = Decision_Tree_Regressor.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = Decision_Tree_Regressor.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9969035974419553 mse: 0.00041062328081676523 rmse: 0.020263841709230884 mae: 0.0025732222819279185 ev: 0.9969038607699355
# r2_train: 1.0 mse_train: 2.9204679897446632e-30 rmse_training: 1.7089376787187599e-15 mae_training: 6.451684266665281e-16 ev_training: 1.0
# normal dataset:
# Cross-validation score for normal dataset: [0.93561325 0.96645952 0.97546094 0.97691204 0.96433245]
# Average cross-validation score for normal dataset: 0.9637556391174309
# R2 Score for normal dataset: [0.93522056 0.96091318 0.97628632 0.97719741 0.96533538]
# Average R2 score for normal dataset: 0.9629905698296369
# MSE score for normal dataset: [-0.00735929 -0.00388133 -0.00259498 -0.00377607 -0.00509401]
# Average MSE score for normal dataset: -0.004541137417920984
# RMSE score for normal dataset: [-0.08930866 -0.0681973  -0.05413642 -0.06225639 -0.06815332]
# Average RMSE score for normal dataset: -0.0684104181570234
# ...

# %%
#univariaate feature selection (f_regressor) 
import sklearn
from sklearn.ensemble import RandomForestRegressor
import numpy as np 
import pandas as pd 

X = df_loftool_log[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_log['LoFtool'] 

Random_Forest_Regressor = RandomForestRegressor() 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

Random_Forest_Regressor.fit(X_train, y_train) 

y_pred = Random_Forest_Regressor.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = Random_Forest_Regressor.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9983998759263486 mse: 0.00021219727878391852 rmse: 0.014566992784508357 mae: 0.0036686533745302944 ev: 0.9984002120439981
# r2_train: 0.9997671441128229 mse_train: 3.0627243460233415e-05 rmse_training: 0.0055341885999876635 mae_training: 0.001310784043410333 ev_training: 0.9997671766756803
# normal dataset:
# Cross-validation score for normal dataset: [0.95299544 0.97838628 0.98065231 0.98378891 0.97367351]
# Average cross-validation score for normal dataset: 0.9738992913717885
# R2 Score for normal dataset: [0.95644907 0.97984692 0.97951706 0.98365309 0.97427248]
# Average R2 score for normal dataset: 0.9747477225442932
# MSE score for normal dataset: [-0.00504678 -0.00264182 -0.002286   -0.00296382 -0.00372245]
# Average MSE score for normal dataset: -0.0033321745517261546
# RMSE score for normal dataset: [-0.07017197 -0.05058178 -0.04656873 -0.05233229 -0.05796239]
# Average RMSE score for normal dataset: -0.055523433406262965
# ...

# %%
#univariate feature selection (f-regression) 
import xgboost as xgb 
import numpy as np 
import pandas as pd 

XGB = xgb.XGBRegressor()

X = df_loftool_log[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_log['LoFtool'] 

XGB = xgb.XGBRegressor()

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

XGB.fit(X_train, y_train) 

y_pred = XGB.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = XGB.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("log dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(XGB, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(XGB, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(XGB, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(XGB, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(XGB, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(XGB, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9973358722272541 mse: 0.0003532980179588909 rmse: 0.018796223502578674 mae: 0.008371724343681167 ev: 0.997335872500697
# r2_train: 0.9987802980392536 mse_train: 0.00016042587264407536 rmse_training: 0.012665933548068036 mae_training: 0.006247137577754999 ev_training: 0.9987802980519491
# log dataset:
# Cross-validation score for log dataset: [0.95469241 0.97799946 0.96721594 0.98753028 0.97241564]
# Average cross-validation score for log dataset: 0.9719707447347888
# R2 Score for log dataset: [0.95469241 0.97799946 0.96721594 0.98753028 0.97241564]
# Average R2 score for log dataset: 0.9719707447347888
# MSE score for log dataset: [-0.0049533  -0.00269659 -0.00356603 -0.00208334 -0.00367706]
# Average MSE score for log dataset: -0.003395264305069177
# RMSE score for log dataset: [-0.07037968 -0.05192867 -0.05971627 -0.04564366 -0.06063876]
# Average RMSE score for log dataset: -0.05766140736316988
# ...

# %%
#univariate feature selection (f-regression)  
import numpy as np 
import pandas as pd 
from sklearn.svm import SVR 

SVR = SVR()

X = df_loftool_log[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_log['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

SVR.fit(X_train, y_train) 

y_pred = SVR.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = SVR.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.02374948117647091 mse: 0.12946352530839336 rmse: 0.3598104018902085 mae: 0.27710323608368126 ev: 0.07715045261423059
# r2_train: 0.044522313973915706 mse_train: 0.1256727844225766 rmse_training: 0.3545035746259501 mae_training: 0.27166975294434326 ev_training: 0.09173904655663279
# normal dataset:
# Cross-validation score for normal dataset: [-0.15948069 -0.37652776 -0.1826151  -0.23733281 -0.6584407 ]
# Average cross-validation score for normal dataset: -0.3228794094479487
# R2 Score for normal dataset: [-0.15948069 -0.37652776 -0.1826151  -0.23733281 -0.6584407 ]
# Average R2 score for normal dataset: -0.3228794094479487
# MSE score for normal dataset: [-0.12676143 -0.16871975 -0.12863703 -0.206724   -0.22107393]
# Average MSE score for normal dataset: -0.1703832287892062
# RMSE score for normal dataset: [-0.35603572 -0.41075509 -0.35866005 -0.45466911 -0.470185  ]
# Average RMSE score for normal dataset: -0.41006099419844516
# ...

# %%
#univariate feature selection (f-regression) (POS, cDNA_position, CDS_positon, Protein_positon removed) 
import numpy as np 
import pandas as pd 
from sklearn.svm import SVR 

SVR = SVR()

X = df_loftool_log[['STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_log['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

SVR.fit(X_train, y_train) 

y_pred = SVR.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = SVR.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9304843050772645 mse: 0.009218685937094954 rmse: 0.09601398823658433 mae: 0.07321554657860681 ev: 0.9305789677544671
# r2_train: 0.9321071652734223 mse_train: 0.008929859595065301 rmse_training: 0.09449793434284848 mae_training: 0.07267378201788754 ev_training: 0.932217880892016
# normal dataset:
# Cross-validation score for normal dataset: [0.8876057  0.9135517  0.89562933 0.95273383 0.93161986]
# Average cross-validation score for normal dataset: 0.9162280850425988
# R2 Score for normal dataset: [0.8876057  0.9135517  0.89562933 0.95273383 0.93161986]
# Average R2 score for normal dataset: 0.9162280850425988
# MSE score for normal dataset: [-0.01228762 -0.01059589 -0.01135275 -0.00789687 -0.00911523]
# Average MSE score for normal dataset: -0.010249671355275708
# RMSE score for normal dataset: [-0.11084955 -0.10293633 -0.10654928 -0.08886431 -0.09547371]
# Average RMSE score for normal dataset: -0.10093463787505982
# ...

# %%
#RANSAC
#univariate feature selection (f regression) 
import numpy as np 
import pandas as pd 
from sklearn.linear_model import RANSACRegressor

RANSAC = RANSACRegressor()

X = df_loftool_log[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_log['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

RANSAC.fit(X_train, y_train) 

y_pred = RANSAC.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = RANSAC.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.890045305122183 mse: 0.014581423670069394 rmse: 0.12075356586896055 mae: 0.0640338631953042 ev: 0.890220756792229
# r2_train: 0.8879593315919528 mse_train: 0.014736568915562838 rmse_training: 0.1213942705219766 mae_training: 0.06281228323207358 ev_training: 0.8880106759112338
# normal dataset:
# Cross-validation score for normal dataset: [0.75757996 0.91545634 0.86218095 0.92635232 0.43283911]
# Average cross-validation score for normal dataset: 0.7788817323193349
# R2 Score for normal dataset: [ 0.7980738   0.5303279  -1.97122713  0.82330517  0.90197735]
# Average R2 score for normal dataset: 0.21649141836744565
# MSE score for normal dataset: [-2.08401601e-02 -1.25513814e-02 -3.96838220e-02 -1.37004133e-02
#  -3.48400239e+01]
# Average MSE score for normal dataset: -6.985359936672353
# RMSE score for normal dataset: [-0.1441215  -0.10635687 -0.29670082 -0.11860052 -0.11470992]
# Average RMSE score for normal dataset: -0.1560979255708656
# ...

# %%
#RANSAC (w/ POS, cDNA_position, CDS_position, Protein_position removed) 
import numpy as np 
import pandas as pd 
from sklearn.linear_model import RANSACRegressor

RANSAC = RANSACRegressor()

X = df_loftool_log[['STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_log['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

RANSAC.fit(X_train, y_train) 

y_pred = RANSAC.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = RANSAC.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9029473986814461 mse: 0.012870438135276701 rmse: 0.11344795342039758 mae: 0.06282456546112102 ev: 0.9031361737107699
# r2_train: 0.9070557710239121 mse_train: 0.012224838133075577 rmse_training: 0.11056598994752219 mae_training: 0.06059856458628797 ev_training: 0.9071458219830641
# normal dataset:
# Cross-validation score for normal dataset: [  0.81848692   0.91591358 -20.17802332   0.92563244   0.89603418]
# Average cross-validation score for normal dataset: -3.324391240613104
# R2 Score for normal dataset: [0.81923082 0.91481759 0.92744872 0.92640084 0.90216019]
# Average R2 score for normal dataset: 0.8980116309666231
# MSE score for normal dataset: [-0.0199488  -0.01029713 -0.00789537 -0.01235332 -0.01336088]
# Average MSE score for normal dataset: -0.01277109850387877
# RMSE score for normal dataset: [-0.14131038 -0.10152065 -0.08827228 -0.11089029 -0.11332578]
# Average RMSE score for normal dataset: -0.11106387617724715
# ...
