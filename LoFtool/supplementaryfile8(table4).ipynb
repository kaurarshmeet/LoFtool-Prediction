# %%
"""
Supplementary File 8: Running Models//Table 4
- took input from CHATGPT in this code 
- learned from: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
- learned from: https://scikit-learn.org/0.15/modules/model_evaluation.html
""""

# %%
#read stuff in 
import numpy as np 
import pandas as pd 
df_loftool_yj = pd.read_csv('df_loftool_yj.csv')

# %%
#Univariate Feature Selection (F Regression)

#got input from chatgpt here
#learned from here too: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
#learned (also) from here: https://stephenallwright.com/cross_val_score-sklearn
#https://grsahagian.medium.com/what-is-random-state-42-d803402ee76b 

import sklearn
from sklearn.neighbors import KNeighborsRegressor
import numpy as np 
import pandas as pd 

KNN = KNeighborsRegressor()

X = df_loftool_yj[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_yj['LoFtool'] 

#regular evaluation 
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 41)  
KNN.fit(X_train, y_train) 

y_pred = KNN.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = KNN.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training) 

#cross validation 
print("Loftool dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score :", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.8902620207001044 mse: 0.01457860525322148 rmse: 0.12074189518647403 mae: 0.039480597264911356 ev: 0.8902766887076894
# r2_train: 0.937135179373195 mse_train: 0.008261710318303259 rmse_training: 0.09089395094451148 mae_training: 0.027571620302448772 ev_training: 0.9371524090541774
# Loftool dataset:
# Cross-validation score: [0.09171079 0.40643756 0.56050495 0.6160061  0.44038318]
# Average cross-validation score: 0.4230085143994174
# R2 Score: [0.09171079 0.40643756 0.56050495 0.6160061  0.44038318]
# Average R2 score: 0.4230085143994174
# MSE score: [-0.09929966 -0.07275241 -0.04780536 -0.06415473 -0.0745982 ]
# Average MSE score: -0.071722071802825
# RMSE score: [-0.31511849 -0.26972654 -0.21864437 -0.25328785 -0.27312671]
# Average RMSE score: -0.26598078987466334
# MAE score : [-0.20131463 -0.16869899 -0.13253931 -0.13637565 -0.18024766]
# Average MAE score: -0.1638352491762493
# Explained Variance: [0.1019479  0.44329399 0.56777619 0.61746904 0.45866985]
# Average Explained Variance: 0.43783139234512236

# %%
#Univariate Feature Selection (F Regression) (POS, cDNA, CDS_positon, Protein_positon removed) 

#knn 
#got input from chatgpt here
#learned from here too: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
#learned (also) from here: https://stephenallwright.com/cross_val_score-sklearn
#https://grsahagian.medium.com/what-is-random-state-42-d803402ee76b 

import sklearn
from sklearn.neighbors import KNeighborsRegressor
import numpy as np 
import pandas as pd 

KNN = KNeighborsRegressor()

X = df_loftool_yj[['STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_yj['LoFtool'] 

#regular evaluation 
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 41)  
KNN.fit(X_train, y_train) 

y_pred = KNN.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = KNN.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training) 

#cross validation 
print("Loftool dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(KNN, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(KNN, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9823696798616192 mse: 0.0023421743267476036 rmse: 0.04839601560818415 mae: 0.020246536455310778 ev: 0.98238626579445
# r2_train: 0.9892791674829454 mse_train: 0.0014089344683373582 rmse_training: 0.03753577584568298 mae_training: 0.015230701210562688 ev_training: 0.9892847836581667
# Loftool dataset:
# Cross-validation score: [0.94491611 0.96604555 0.91787503 0.96908461 0.95357494]
# Average cross-validation score: 0.950299247911568
# R2 Score: [0.94491611 0.96604555 0.91787503 0.96908461 0.95357494]
# Average R2 score: 0.950299247911568
# MSE score: [-0.0060221  -0.00416177 -0.00893301 -0.0051651  -0.00618857]
# Average MSE score: -0.006094110017818151
# RMSE score: [-0.07760221 -0.06451175 -0.0945146  -0.07186866 -0.07866744]
# Average RMSE score: -0.07743293322156881
# MAE score: [-0.0484125  -0.03591622 -0.05505183 -0.03554953 -0.04724637]
# Average MAE score: -0.04443528955937669
# Explained Variance: [0.9449222  0.96691963 0.91928871 0.96981708 0.95404247]
# Average Explained Variance: 0.9509980153132835

# %%
#Univariate feature selection (f regression) 
import sklearn
from sklearn.tree import DecisionTreeRegressor
import numpy as np 
import pandas as pd 

X = df_loftool_yj[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_yj['LoFtool'] 

Decision_Tree_Regressor = DecisionTreeRegressor() 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

Decision_Tree_Regressor.fit(X_train, y_train) 

y_pred = Decision_Tree_Regressor.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = Decision_Tree_Regressor.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(Decision_Tree_Regressor, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.997370156202642 mse: 0.00034875151659502057 rmse: 0.01867489000222011 mae: 0.002387307003403835 ev: 0.9973707668758337
# r2_train: 1.0 mse_train: 2.9163867982730428e-30 rmse_training: 1.7077431886185472e-15 mae_training: 6.503479618105823e-16 ev_training: 1.0
# normal dataset:
# Cross-validation score: [0.92817051 0.96642535 0.97631794 0.97594097 0.96133641]
# Average cross-validation score: 0.9616382365271494
# R2 Score: [0.92822628 0.96630785 0.97521022 0.97650948 0.96120427]
# Average R2 score: 0.9614916211680871
# MSE score: [-0.00786954 -0.00416462 -0.00271011 -0.00365613 -0.0052993 ]
# Average MSE score: -0.00473994286364425
# RMSE score: [-0.08976435 -0.06491311 -0.05237105 -0.06411601 -0.07269569]
# Average RMSE score: -0.0687720424634427
# MAE score: [-0.04088433 -0.02722051 -0.01840094 -0.0187064  -0.02411034]
# Average MAE score: -0.02586450405695868
# Explained Variance: [0.92812394 0.969511   0.97501361 0.97617859 0.96183312]
# Average Explained Variance: 0.9621320518544344

# %%
#univariaate feature selection (f_regressor) 
import sklearn
from sklearn.ensemble import RandomForestRegressor
import numpy as np 
import pandas as pd 

X = df_loftool_yj[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']]
y = df_loftool_yj['LoFtool'] 

Random_Forest_Regressor = RandomForestRegressor() 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

Random_Forest_Regressor.fit(X_train, y_train) 

y_pred = Random_Forest_Regressor.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = Random_Forest_Regressor.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(Random_Forest_Regressor, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9984690065015117 mse: 0.00020302966473951855 rmse: 0.014248847839019075 mae: 0.003583426582483015 ev: 0.9984692471637755
# r2_train: 0.9997629781692206 mse_train: 3.117518480925936e-05 rmse_training: 0.0055834742597471836 mae_training: 0.0013253191300764897 ev_training: 0.9997630132343746
# normal dataset:
# Cross-validation score: [0.95560014 0.97887824 0.9794786  0.9841524  0.97244377]
# Average cross-validation score: 0.9741106292390385
# R2 Score: [0.95541723 0.97882531 0.98051128 0.98332494 0.97437897]
# Average R2 score: 0.9744915459010512
# MSE score: [-0.00495416 -0.0025401  -0.00221948 -0.00262818 -0.00371601]
# Average MSE score: -0.003211587202696144
# RMSE score: [-0.07134602 -0.05220353 -0.04587476 -0.05261187 -0.0594481 ]
# Average RMSE score: -0.056296854222187664
# MAE score: [-0.03572844 -0.02751353 -0.02054627 -0.02102084 -0.02875185]
# Average MAE score: -0.02671218535478253
# Explained Variance: [0.95544314 0.9817502  0.97997561 0.9833112  0.97522804]
# Average Explained Variance: 0.9751416373498575

# %%
#univariate feature selection (f-regression) 
import xgboost as xgb 
import numpy as np 
import pandas as pd 

XGB = xgb.XGBRegressor()

X = df_loftool_yj[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_yj['LoFtool'] 

XGB = xgb.XGBRegressor()

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

XGB.fit(X_train, y_train) 

y_pred = XGB.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = XGB.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("log dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(XGB, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(XGB, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(XGB, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(XGB, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(XGB, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(XGB, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9973358722272541 mse: 0.0003532980179588909 rmse: 0.018796223502578674 mae: 0.008371724343681167 ev: 0.997335872500697
# r2_train: 0.9987802980392536 mse_train: 0.00016042587264407536 rmse_training: 0.012665933548068036 mae_training: 0.006247137577754999 ev_training: 0.9987802980519491
# log dataset:
# Cross-validation score: [0.95469511 0.97800158 0.96721594 0.98752715 0.97241561]
# Average cross-validation score: 0.971971079166339
# R2 Score: [0.95469511 0.97800158 0.96721594 0.98752715 0.97241561]
# Average R2 score: 0.971971079166339
# MSE score: [-0.004953   -0.00269633 -0.00356603 -0.00208387 -0.00367706]
# Average MSE score: -0.003395258401591545
# RMSE score: [-0.07037758 -0.05192616 -0.05971627 -0.04564939 -0.06063879]
# Average RMSE score: -0.05766163728129788
# MAE score: [-0.04064379 -0.02980106 -0.03288427 -0.02061365 -0.03639967]
# Average MAE score: -0.03206848724374066
# Explained Variance: [0.95502122 0.97970973 0.96728101 0.98769144 0.97360229]
# Average Explained Variance: 0.972661138385728

# %%
#univariate feature selection (f-regression) 
import numpy as np 
import pandas as pd 
from sklearn.svm import SVR 

SVR = SVR()

X = df_loftool_yj[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_yj['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

SVR.fit(X_train, y_train) 

y_pred = SVR.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = SVR.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.023677712981202248 mse: 0.12947304270519405 rmse: 0.359823627219217 mae: 0.2770421545122638 ev: 0.0768018049359549
# r2_train: 0.044424444735610136 mse_train: 0.12568565704102397 rmse_training: 0.3545217299983514 mae_training: 0.27161888989466726 ev_training: 0.0913742067709048
# normal dataset:
# Cross-validation score: [-0.16014039 -0.377782   -0.18332385 -0.23850994 -0.65621312]
# Average cross-validation score: -0.3231938591586677
# R2 Score: [-0.16014039 -0.377782   -0.18332385 -0.23850994 -0.65621312]
# Average R2 score: -0.3231938591586677
# MSE score: [-0.12683355 -0.16887348 -0.12871413 -0.20692067 -0.22077699]
# Average MSE score: -0.1704237631522511
# RMSE score: [-0.35613699 -0.41094218 -0.35876751 -0.45488533 -0.46986912]
# Average RMSE score: -0.4101202271176062
# MAE score: [-0.27317464 -0.30416097 -0.25971185 -0.36683651 -0.40861984]
# Average MAE score: -0.3225007640967097
# Explained Variance: [-0.16012159 -0.01212728 -0.00544065  0.09986455 -0.44185874]
# Average Explained Variance: -0.10393674504523023

# %%
#univariate feature selection (f-regression) (POS, cDNA_position, CDS_positon, Protein_positon removed) 
import numpy as np 
import pandas as pd 
from sklearn.svm import SVR 

SVR = SVR()

X = df_loftool_yj[['STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_yj['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

SVR.fit(X_train, y_train) 

y_pred = SVR.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = SVR.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(SVR, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(SVR, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.930484305077266 mse: 0.009218685937094757 rmse: 0.0960139882365833 mae: 0.07321554657860439 ev: 0.9305789677544682
# r2_train: 0.9321071652734236 mse_train: 0.008929859595065131 rmse_training: 0.09449793434284758 mae_training: 0.07267378201788517 ev_training: 0.9322178808920167
# normal dataset:
# Cross-validation score: [0.8876057  0.9135517  0.89562933 0.95273383 0.93161986]
# Average cross-validation score: 0.9162280850425992
# R2 Score: [0.8876057  0.9135517  0.89562933 0.95273383 0.93161986]
# Average R2 score: 0.9162280850425992
# MSE score: [-0.01228762 -0.01059589 -0.01135275 -0.00789687 -0.00911523]
# Average MSE score: -0.010249671355275639
# RMSE score: [-0.11084955 -0.10293633 -0.10654928 -0.08886431 -0.09547371]
# Average RMSE score: -0.10093463787505945
# MAE score: [-0.08191842 -0.08585276 -0.08652553 -0.0579037  -0.07598048]
# Average MAE score: -0.077636176915082
# Explained Variance: [0.88790309 0.91423298 0.90003521 0.95381562 0.93248621]
# Average Explained Variance: 0.9176946197478056

# %%
#RANSAC
#univariate feature selection (f regression) 
import numpy as np 
import pandas as pd 
from sklearn.linear_model import RANSACRegressor

RANSAC = RANSACRegressor()

X = df_loftool_yj[['POS', 'cDNA_position', 'CDS_position', 'Protein_position', 'STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_yj['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

RANSAC.fit(X_train, y_train) 

y_pred = RANSAC.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = RANSAC.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance for normal dataset:", explained_variance) 
print("Average Explained Variance for normal dataset:", explained_variance.mean())
# Out:
# r2: 0.898870126602671 mse: 0.013411137481173927 rmse: 0.11580646562767524 mae: 0.06361184634838837 ev: 0.9000395414501455
# r2_train: 0.9031754618846823 mse_train: 0.012735210338600917 rmse_training: 0.11285038918231925 mae_training: 0.061340310450303415 ev_training: 0.9040742120287295
# normal dataset:
# Cross-validation score: [0.8123556  0.90943211 0.9292013  0.92416622 0.90118433]
# Average cross-validation score: 0.8952679111240933
# R2 Score: [-29.68381611   0.90579055   0.93028842   0.91673067   0.90193953]
# Average R2 score: -5.20581338983432
# MSE score: [-0.02082374 -0.01043146 -0.00854727 -0.01240018 -0.013061  ]
# Average MSE score: -0.013052730895957366
# RMSE score: [-8.28448448 -0.10164891 -1.17649443 -0.11161871 -0.11504274]
# Average RMSE score: -1.9578578561384685
# MAE score: [-0.08947139 -0.05140869 -0.04603078 -0.0750914  -0.06397734]
# Average MAE score: -0.0651959189233992
# Explained Variance for normal dataset: [0.81974911 0.89591137 0.92932706 0.92586426 0.90307396]
# Average Explained Variance for normal dataset: 0.8947851520229783

# %%
#RANSAC (w/ POS, cDNA_position, CDS_position, Protein_position removed) 
import numpy as np 
import pandas as pd 
from sklearn.linear_model import RANSACRegressor

RANSAC = RANSACRegressor()

X = df_loftool_yj[['STRAND', 'CHROM', 'SYMBOL', 'Feature', 'EXON', 'Codons']] 
y = df_loftool_yj['LoFtool'] 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.3, random_state = 42) 

RANSAC.fit(X_train, y_train) 

y_pred = RANSAC.predict(X_test)
r2 = sklearn.metrics.r2_score(y_test,y_pred) 
mse = sklearn.metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) 
mae = sklearn.metrics.mean_absolute_error(y_test, y_pred) 
ev = sklearn.metrics.explained_variance_score(y_test, y_pred) 
print("r2:", r2, "mse:", mse, "rmse:", rmse, "mae:", mae, "ev:", ev) 

y_pred_training = RANSAC.predict(X_train) 
r2_training = sklearn.metrics.r2_score(y_train, y_pred_training) 
mse_training = sklearn.metrics.mean_squared_error(y_train, y_pred_training)
rmse_training = np.sqrt(mse_training)
mae_training = sklearn.metrics.mean_absolute_error(y_train, y_pred_training)
ev_training = sklearn.metrics.explained_variance_score(y_train, y_pred_training)
print("r2_train:", r2_training, "mse_train:", mse_training, "rmse_training:", rmse_training, "mae_training:", mae_training, "ev_training:", ev_training)

#cross validation 
print("normal dataset:") 
cross_validation = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5)
sklearn.metrics.get_scorer_names()
print("Cross-validation score:", cross_validation)
print("Average cross-validation score:", cross_validation.mean()) 

r2 = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'r2')
print("R2 Score:", r2) 
print("Average R2 score:", r2.mean()) 

mse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_squared_error') 
print("MSE score:", mse) 
print("Average MSE score:", mse.mean()) 

rmse = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_root_mean_squared_error') 
print("RMSE score:", rmse)
print("Average RMSE score:", rmse.mean()) 

mae = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv=5, scoring = 'neg_mean_absolute_error') 
print("MAE score:", mae) 
print("Average MAE score:", mae.mean()) 

explained_variance = sklearn.model_selection.cross_val_score(RANSAC, X, y, cv = 5, scoring = 'explained_variance') 
print("Explained Variance:", explained_variance) 
print("Average Explained Variance:", explained_variance.mean())
# Out:
# r2: 0.9015419701463233 mse: 0.013056816251567262 rmse: 0.11426642661590176 mae: 0.06173819516355592 ev: 0.9024058621655826
# r2_train: 0.9057104816867142 mse_train: 0.012401782356192739 rmse_training: 0.11136328998459384 mae_training: 0.059544012350381904 ev_training: 0.9063582207951502
# normal dataset:
# Cross-validation score: [0.81331889 0.91430462 0.93020368 0.92641438 0.90244382]
# Average cross-validation score: 0.8973370784985255
# R2 Score: [0.49959634 0.91559156 0.9302126  0.92648855 0.90064827]
# Average R2 score: 0.8345074638689749
# MSE score: [-1.99153807e-02 -1.03243732e-02 -2.53671697e+02 -1.23401883e-02
#  -1.31586266e-02]
# Average MSE score: -50.74548707210754
# RMSE score: [-0.14066965 -0.10162358 -0.08729569 -0.11088556 -0.11417848]
# Average RMSE score: -0.11093059188301
# MAE score: [-0.0894035  -0.04986607 -0.0542881  -0.05630368 -0.06877298]
# Average MAE score: -0.0637268663470834
# Explained Variance: [0.82222482 0.91618929 0.56378648 0.92658001 0.90248159]
# Average Explained Variance: 0.826252436401792
